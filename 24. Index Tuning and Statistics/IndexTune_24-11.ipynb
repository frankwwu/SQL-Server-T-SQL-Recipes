-- %%
/* 24-11 */
USE AdventureWorks2014;
GO
DBCC SHOW_STATISTICS ( 'Sales.Customer' , AK_Customer_AccountNumber);
-- Out:
-- Commands completed successfully.
-- (1 row affected)
-- (2 rows affected)
-- (152 rows affected)
-- DBCC execution completed. If DBCC printed error messages, contact your system administrator.
-- Total execution time: 00:00:00.399
-- <table><tr><th>Name</th><th>Updated</th><th>Rows</th><th>Rows Sampled</th><th>Steps</th><th>Density</th><th>Average key length</th><th>String Index</th><th>Filter Expression</th><th>Unfiltered Rows</th><th>Persisted Sample Percent</th></tr><tr><td>AK_Customer_AccountNumber</td><td>Oct 20 2020  5:03PM</td><td>19820</td><td>19820</td><td>152</td><td>1</td><td>14</td><td>YES</td><td>NULL</td><td>19820</td><td>0</td></tr></table>
-- <table><tr><th>All density</th><th>Average Length</th><th>Columns</th></tr><tr><td>5.0454088E-05</td><td>10</td><td>AccountNumber</td></tr><tr><td>5.0454088E-05</td><td>14</td><td>AccountNumber, CustomerID</td></tr></table>
-- ...
