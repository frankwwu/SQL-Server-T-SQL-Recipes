><tr><td>2010-01-17</td></tr><tr><td>2010-01-22</td></tr><tr><td>2010-01-23</td></tr><tr><td>2010-01-24</td></tr><tr><td>2010-01-27</td></tr><tr><td>2010-01-29</td></tr><tr><td>2010-01-31</td></tr><tr><td>2010-02-01</td></tr><tr><td>2010-02-05</td></tr><tr><td>2010-02-08</td></tr><tr><td>2010-02-12</td></tr><tr><td>2010-02-13</td></tr><tr><td>2010-02-16</td></tr><tr><td>2010-02-20</td></tr><tr><td>2010-02-23</td></tr><tr><td>2010-02-27</td></tr><tr><td>2010-03-03</td></tr><tr><td>2010-03-04< ...

-- %%
-- 6-2. Returning the Top N Rows

SELECT TOP (5) HireDate
FROM HumanResources.Employee
GROUP BY HireDate
ORDER BY HireDate DESC;
-- Out:
-- (5 rows affected)
-- Total execution time: 00:00:00.379
-- <table><tr><th>HireDate</th></tr><tr><td>2013-05-30</td></tr><tr><td>2013-03-14</td></tr><tr><td>2012-09-30</td></tr><tr><td>2012-05-30</td></tr><tr><td>2012-04-16</td></tr></table>

-- %%
-- 6-3. Renaming a Column in the Output

SELECT ss.name AS SchemaName,
       TableName = st.name,
       st.object_id ObjectId
FROM sys.schemas AS ss
     JOIN sys.tables st
        ON ss.schema_id = st.schema_id
ORDER BY SchemaName, TableName;
-- Out:
-- (81 rows affected)
-- Total execution time: 00:00:00.137
-- <table><tr><th>SchemaName</th><th>TableName</th><th>ObjectId</th></tr><tr><td>dbo</td><td>AWBuildVersion</td><td>469576711</td></tr><tr><td>dbo</td><td>CustomerAccount</td><td>1172199226</td></tr><tr><td>dbo</td><td>DatabaseLog</td><td>245575913</td></tr><tr><td>dbo</td><td>DimProductSalesperson</td><td>1076198884</td></tr><tr><td>dbo</td><td>ErrorLog</td><td>277576027</td></tr><tr><td>dbo</td><td>Heap_Shift</td><td>1668200993</td></tr><tr><td>dbo</td><td>InventoryAccount</td><td>1156199169</td></tr><tr><td>dbo</td><td>Person</td><td>548197003</td></tr><tr><td>dbo</td><td>PhoneNumberType</td><td>580197117</td></tr><tr><td>dbo</td><td>Staging_PRODSLSP</td><td>1108198998</td></tr><tr><td>dbo</td><td>TypedXML_VS</td><td>983674552</td></tr><tr><td>dbo</td><td>UntypedXML</td><td>935674381</td></tr><tr><td>HumanResources</td><td>Department</td><td>1045578763</td></tr><tr><td>HumanResources</td><td>Employee</td><td>1237579447</td></tr><tr><td>HumanResources</td><td>EmployeeDepartmentHistory</td><td>1445580188</td></tr><tr><td>HumanResources</td><td>EmployeePayHistory</td><td>1493580359</td></tr><tr><td>HumanResources</td><td>JobCandidate</td><td>1589580701</td></tr><tr><td>HumanResources</td><td>Shift</td><td>46623209</td></tr><tr><td>Person</td><td>Address</td><td>373576369</td></tr><tr><td>Person</td><td>AddressType</td><td>421576540</td></tr><tr><td>Person</td><td>BusinessEntity</td><td>629577281</td></tr><tr><td>Person</td><td>BusinessEntityAddress</td><td>677577452</td></tr><tr><td>Person</td><td>BusinessEntityContact</td><td>725577623</td></tr><tr><td>Person</td><td>ContactType</td><td>773577794</td></tr><tr><td>Person</td><td>CountryRegion</td><td>837578022</td></tr><tr><td>Person</td><td>EmailAddress</td><td>1189579276</td></tr><tr><td>Person</td><td>Password</td><td>1717581157</td></tr><tr><td>Person</td><td>PasswordCopy</td><td>1988202133</td></tr><tr><td>Person</td><td>Person</td><td>1765581328</td></tr><tr><td>Person</td><td>PersonPhone</td><td>1909581841</td></tr><tr><td>Person</td><td>PhoneNumberType</td><td>1941581955</td></tr><tr><td>Person</td><td>StateProvince</td><td>462624691</td></tr><tr><td>Production</td><td>BillOfMaterials</td><td>501576825</td></tr><tr><td>Production</td><td>Culture</td><td>901578250</td></tr><tr><td>Production</td><td>Document</td><td>1077578877</td></tr><tr><td>Production</td><td>Illustration</td><td>1557580587</td></tr><tr><td>Production</td><td>Location</td><td>1621580815</td></tr><tr><td>Production</td><td>Product</td><td>1973582069</td></tr><tr><td>Production</td><td>ProductCategory</td><td>66099276</td></tr><tr><td>Production</td><td>ProductCostHistory</td><td>114099447</td></tr><tr><td>Production</td><td>ProductDescription</td><td>178099675</td></tr><tr><td>Production</td><td>ProductDocument</td><td>226099846</td></tr><tr><td>Production</td><td>ProductInventory</td><td>258099960</td></tr><tr><td>Production</td><td>ProductListPriceHistory</td><td>354100302</td></tr><tr><td>Production</td><td>ProductModel</td><td>418100530</td></tr><tr><td>Production</td><td>ProductModelIllustration</td><td>466100701</td></tr><tr><td>Production</td><td>ProductModelProductDescriptionCulture</td><td>498100815</td></tr><tr><td>Production</td><td>ProductPhoto</td><td>530100929</td></tr><tr><td>Production</td><td>ProductProductPhoto</td><td>562101043</td></tr><tr><td>Production</td><td>ProductReview</td><td>610101214</td></tr><tr><td>Production</td><td>ProductSubcategory</td><td>674101442</td></tr><tr><td>Production</td><td>ScrapReason</td><td>14623095</td></tr><tr><td>Production</td><td>TransactionHistory</td><td>574625090</td></tr><tr><td>Production</td><td>TransactionHistoryArchive</td><td>654625375</td></tr><tr><td>Production</td><td>UnitMeasure</td><td>734625660</td></tr><tr><td>Production</td><td>WorkOrder</td><td>846626059</td></tr><tr><td>Production</td><td>WorkOrderRouting</td><td>926626344</td></tr><tr><td>Purchasing</td><td>ProductVendor</td><td>722101613</td></tr><tr><td>Purchasing</td><td>Purcha ...

-- %%
-- 6-4. Retrieving Data Directly into Variables

DECLARE @FirstHireDate DATE,
        @LastHireDate DATE;
SELECT @FirstHireDate = MIN(HireDate),
       @LastHireDate = MAX(HireDate)
FROM HumanResources.Employee;
SELECT @FirstHireDate AS FirstHireDate,
       @LastHireDate AS LastHireDate;
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:01.503
-- <table><tr><th>FirstHireDate</th><th>LastHireDate</th></tr><tr><td>2006-06-30</td><td>2013-05-30</td></tr></table>

-- %%
-- 6-5. Creating a New Table with the Results from a Query

SELECT *
INTO #Sales
FROM Sales.SalesOrderDetail
WHERE ModifiedDate = '2005-07-01T00:00:00';
SELECT COUNT(*) AS QtyOfRows
FROM #Sales;
-- Out:
-- (0 rows affected)
-- (1 row affected)
-- Total execution time: 00:00:00.151
-- <table><tr><th>QtyOfRows</th></tr><tr><td>0</td></tr></table>

-- %%
-- 6-6. Filtering on the Results from a Subquery

SELECT s.PurchaseOrderNumber
FROM Sales.SalesOrderHeader s
WHERE EXISTS ( SELECT SalesOrderID
               FROM Sales.SalesOrderDetail
               WHERE UnitPrice BETWEEN 1900 AND 2000
                        AND SalesOrderID = s.SalesOrderID );
-- Out:
-- (7 rows affected)
-- Total execution time: 00:00:00.074
-- <table><tr><th>PurchaseOrderNumber</th></tr><tr><td>PO7569171528</td></tr><tr><td>PO5858172038</td></tr><tr><td>PO2146113582</td></tr><tr><td>PO12586169040</td></tr><tr><td>PO13543119495</td></tr><tr><td>PO10440182311</td></tr><tr><td>PO12586178184</td></tr></table>

-- %%
-- 6-7. Selecting from the Results of Another Query

SELECT DISTINCT
       s.PurchaseOrderNumber
FROM Sales.SalesOrderHeader s
     INNER JOIN (SELECT SalesOrderID
                 FROM Sales.SalesOrderDetail
                 WHERE UnitPrice BETWEEN 1900 AND 2000
                ) dt
        ON s.SalesOrderID = dt.SalesOrderID;
-- Out:
-- (7 rows affected)
-- Total execution time: 00:00:00.056
-- <table><tr><th>PurchaseOrderNumber</th></tr><tr><td>PO10440182311</td></tr><tr><td>PO12586169040</td></tr><tr><td>PO12586178184</td></tr><tr><td>PO13543119495</td></tr><tr><td>PO2146113582</td></tr><tr><td>PO5858172038</td></tr><tr><td>PO7569171528</td></tr></table>

-- %%
-- 6-8. Passing Rows Through a Function

CREATE FUNCTION dbo.fn_WorkOrderRouting (@WorkOrderID INT)
RETURNS TABLE
AS
RETURN
    SELECT WorkOrderID,
           ProductID,
           OperationSequence,
           LocationID
    FROM Production.WorkOrderRouting
    WHERE WorkOrderID = @WorkOrderID;
GO
-- Out:
-- Commands completed successfully.
-- Total execution time: 00:00:00.044

-- %%
SELECT TOP (5)
       w.WorkOrderID,
       w.OrderQty,
       r.ProductID,
       r.OperationSequence
FROM Production.WorkOrder w
     CROSS APPLY dbo.fn_WorkOrderRouting(w.WorkOrderID) AS r
ORDER BY w.WorkOrderID,
         w.OrderQty,
         r.ProductID;
-- Out:
-- (5 rows affected)
-- Total execution time: 00:00:00.054
-- <table><tr><th>WorkOrderID</th><th>OrderQty</th><th>ProductID</th><th>OperationSequence</th></tr><tr><td>13</td><td>4</td><td>747</td><td>1</td></tr><tr><td>13</td><td>4</td><td>747</td><td>2</td></tr><tr><td>13</td><td>4</td><td>747</td><td>3</td></tr><tr><td>13</td><td>4</td><td>747</td><td>4</td></tr><tr><td>13</td><td>4</td><td>747</td><td>6</td></tr></table>

-- %%
-- 6-9. Returning Random Rows from a Table

SELECT FirstName,
       LastName
FROM Person.Person
TABLESAMPLE SYSTEM (2 PERCENT);
-- Out:
-- (790 rows affected)
-- Total execution time: 00:00:00.076
-- <table><tr><th>FirstName</th><th>LastName</th></tr><tr><td>Renee</td><td>Sanz</td></tr><tr><td>Ricky</td><td>Sanz</td></tr><tr><td>Roberto</td><td>Sanz</td></tr><tr><td>Robin</td><td>Sanz</td></tr><tr><td>Robyn</td><td>Sanz</td></tr><tr><td>Rodney</td><td>Sanz</td></tr><tr><td>Ross</td><td>Sanz</td></tr><tr><td>Roy</td><td>Sanz</td></tr><tr><td>Sabrina</td><td>Sanz</td></tr><tr><td>Shannon</td><td>Sanz</td></tr><tr><td>Sheila</td><td>Sanz</td></tr><tr><td>Tabitha</td><td>Sanz</td></tr><tr><td>Tanya</td><td>Sanz</td></tr><tr><td>Theodore</td><td>Sanz</td></tr><tr><td
brenda</td><td>Saunders</td></tr><tr><td>Carol</td><td>Saunders</td></tr><tr><td>Cynthia</td><td>Saunders</td></tr><tr><td>Darren</td><td>Saunders</td></tr><tr><td>Dominique</td><td>Saunders</td></tr><tr><td>Jacquelyn</td><td>Saunders</td></tr><tr><td>Jillian</td><td>Saunders</td></tr><tr><td>Kristi</td><td>Saunders</td></tr><tr><td>Lloyd</td><td>Saunders</td></tr><tr><td>Melody</td><td>Saunders</td></tr><tr><td>Micheal</td><td>Saunders</td></tr><tr><td>Patricia</td><td>Saunders</td></tr><tr><td>Roy</td><td>Saunders</td></tr><tr><td>Ruben</td><td>Saunders</td></tr><tr><td>Ciam</td><td>Sawyer</td></tr><tr><td>Vadim</td><td>Sazanovich</td></tr><tr><td>Jim</td><td>Scardelis</td></tr><tr><td>Jim</td><td>Scardelis</td></tr><tr><td>Gary</td><td>Schare</td></tr><tr><td>Gary</td><td>Schare</td></tr><tr><td>Yvonne</td><td>S ...

-- %%
-- 6-10. Converting Rows into Columns

-- Before pivot
SELECT s.Name AS ShiftName,
       h.BusinessEntityID,
       d.Name AS DepartmentName
FROM HumanResources.EmployeeDepartmentHistory h
    INNER JOIN HumanResources.Department d
        ON h.DepartmentID = d.DepartmentID
    INNER JOIN HumanResources.Shift s
        ON h.ShiftID = s.ShiftID
WHERE EndDate IS NULL
    AND d.Name IN ('Production', 'Engineering', 'Marketing')
ORDER BY ShiftName;
-- Out:
-- (194 rows affected)
-- Total execution time: 00:00:00.053
-- <table><tr><th>ShiftName</th><th>BusinessEntityID</th><th>DepartmentName</th></tr><tr><td>Day</td><td>2</td><td>Engineering</td></tr><tr><td>Day</td><td>3</td><td>Engineering</td></tr><tr><td>Day</td><td>5</td><td>Engineering</td></tr><tr><td>Day</td><td>6</td><td>Engineering</td></tr><tr><td>Day</td><td>14</td><td>Engineering</td></tr><tr><td>Day</td><td>15</td><td>Engineering</td></tr><tr><td>Day</td><td>16</td><td>Marketing</td></tr><tr><td>Day</td><td>17</td><td>Marketing</td></tr><tr><td>Day</td><td>18</td><td>Marketing</td></tr><tr><td>Day</td><td>19</td><td>Marketing</td></tr><tr><td>Day</td><td>20</td><td>Marketing</td></tr><tr><td>Day</td><td>21</td><td>Marketing</td></tr><tr><td>Day</td><td>22</td><td>Marketing</td></tr><tr><td>Day</td><td>23</td><td>Marketing</td></tr><tr><td>Day</td><td>24</td><td>Marketing</td></tr><tr><td>Day</td><td>25</td><td>Production</td></tr><tr><td>Day</td><td>27</td><td>Production</td></tr><tr><td>Day</td><td>28</td><td>Production</td></tr><tr><td>Day</td><td>29</td><td>Production</td></tr><tr><td>Day</td><td>30</td><td>Production</td></tr><tr><td>Day</td><td>31</td><td>Production</td></tr><tr><td>Day</td><td>32</td><td>Production</td></tr><tr><td>Day</td><td>33</td><td>Production</td></tr><tr><td>Day</td><td>34</td><td>Production</td></tr><tr><td>Day</td><td>35</td><td>Production</td></tr><tr><td>Day</td><td>36</td><td>Production</td></tr><tr><td>Day</td><td>37</td><td>Production</td></tr><tr><td>Day</td><td>38</td><td>Production</td></tr><tr><td>Day</td><td>39</td><td>Production</td></tr><tr><td>Day</td><td>47</td><td>Production</td></tr><tr><td>Day</td><td>48</td><td>Production</td></tr><tr><td>Day</td><td>49</td><td>Production</td></tr><tr><td>Day</td><td>50</td><td>Production</td></tr><tr><td>Day</td><td>51</td><td>Production</td></tr><tr><td>Day</td><td>52</td><td>Production</td></tr><tr><td>Day</td><td>53</td><td>Production</td></tr><tr><td>Day</td><td>54</td><td>Production</td></tr><tr><td>Day</td><td>108</td><td>Production</td></tr><tr><td>Day</td><td>109</td><td>Production</td></tr><tr><td>Day</td><td>110</td><td>Production</td></tr><tr><td>Day</td><td>111</td><td>Production</td></tr><tr><td>Day</td><td>112</td><td>Production</td></tr><tr><td>Day</td><td>113</td><td>Production</td></tr><tr><td>Day</td><td>114</td><td>Production</td></tr><tr><td>Day</td><td>115</td><td>Production</td></tr><tr><td>Day</td><td>116</td><td>Production</td></tr><tr><td>Day</td><td>117</td><td>Production</td></tr><tr><td>Day</td><td>118</td><td>Production</td></tr><tr><td>Day</td><td>119</td><td>Production</td></tr><tr><td>Day</td><td>120</td><td>Production</td></tr><tr><td>Day</td><td>134</td><td>Production</td></tr><tr><td>Day</td><td>135</td><td>Production</td></tr><tr><td>Day</td><td>136</td><td>Production</td></tr><tr><td>Day</td><td>137</td><td>Production</td></tr><tr><td>Day</td><td>138</td><td>Production</td></tr><tr><td>Day</td><td>139</td><td>Production</td></tr><tr><td>Day</td><td>140</td><td>Production</td></tr><tr><td>Day</td><td>141</td><td>Production</td></tr><tr><td>Day</td><td>142</td><td>Production</td></tr><tr><td>Day</td><td>143</td><td>Production</td></tr><tr><td>Day</td><td>144</td><td>Production</td></tr><tr><td>Day</td><td>160</td><td>Production</td></tr><tr><td>Day</td><td>161</td><td>Production</td></tr><tr><td>Day</td><td>162</td><td>Production</td></tr><tr><td>Day</td><td>163</td><td>Production</td></tr><tr><td>Day</td><td>164</td><td>Production</td></tr><tr><td>Day</td><td>165</td><td>Production</td></tr><tr><td>Day</td><td>166</td><td>Production</td></tr><tr><td>Day</td><td>167</td><td>Production</td></tr><tr><td>Day</td><td>168</td><td>Production</td></tr><tr><td>Day</td><td>169</td><td>Production</td></tr><tr><td>Day</td><td>170</td><td>Production</td></tr><tr><td>Day</td><td>171</td><td>Production</td></tr><tr><td>Day</td><td>172</td><td>Production</td></tr><tr><td>Day</td><td>173</td><td>Production</td></tr><tr><td>Day</td><td>174</td><td>Production</td></tr><tr><td>Da ...

-- %%
-- Pivot the department values returned from this query into columns, along with a count of employees by shift.

SELECT ShiftName,
       Production,
       Engineering,
       Marketing
FROM (SELECT s.Name AS ShiftName,
        h.BusinessEntityID,
        d.Name AS DepartmentName
    FROM HumanResources.EmployeeDepartmentHistory h
        INNER JOIN HumanResources.Department d
            ON h.DepartmentID = d.DepartmentID
        INNER JOIN HumanResources.Shift s
            ON h.ShiftID = s.ShiftID
    WHERE EndDate IS NULL
        AND d.Name IN ('Production', 'Engineering', 'Marketing')
    ) AS a
PIVOT
(
    COUNT(BusinessEntityID)
    FOR DepartmentName IN ([Production], [Engineering], [Marketing])
) AS b
ORDER BY ShiftName;
-- Out:
-- (3 rows affected)
-- Total execution time: 00:00:00.036
-- <table><tr><th>ShiftName</th><th>Production</th><th>Engineering</th><th>Marketing</th></tr><tr><td>Day</td><td>79</td><td>6</td><td>9</td></tr><tr><td>Evening</td><td>54</td><td>0</td><td>0</td></tr><tr><td>Night</td><td>46</td><td>0</td><td>0</td></tr></table>

-- %%
-- Prior to the introduction of the PIVOT operator, a pivot would be performed through aggregations, calculated columns, and the GROUP BY operator

SELECT s.Name AS ShiftName,
       SUM(CASE WHEN d.Name = 'Production' THEN 1 ELSE 0 END) AS Production,
       SUM(CASE WHEN d.Name = 'Engineering' THEN 1 ELSE 0 END) AS Engineering,
       SUM(CASE WHEN d.Name = 'Marketing' THEN 1 ELSE 0 END) AS Marketing
FROM HumanResources.EmployeeDepartmentHistory h
    INNER JOIN HumanResources.Department d
        ON h.DepartmentID = d.DepartmentID
    INNER JOIN HumanResources.Shift s
        ON h.ShiftID = s.ShiftID
WHERE h.EndDate IS NULL
    AND d.Name IN ('Production', 'Engineering', 'Marketing')
GROUP BY s.Name;
-- Out:
-- (3 rows affected)
-- Total execution time: 00:00:00.071
-- <table><tr><th>ShiftName</th><th>Production</th><th>Engineering</th><th>Marketing</th></tr><tr><td>Day</td><td>79</td><td>6</td><td>9</td></tr><tr><td>Evening</td><td>54</td><td>0</td><td>0</td></tr><tr><td>Night</td><td>46</td><td>0</td><td>0</td></tr></table>

-- %%
-- 6-11. Converting Columns into Rows

CREATE TABLE dbo.Contact
    (
    EmployeeID INT NOT NULL,
    PhoneNumber1 BIGINT,
    PhoneNumber2 BIGINT,
    PhoneNumber3 BIGINT
    )
GO
INSERT dbo.Contact
    (EmployeeID, PhoneNumber1, PhoneNumber2, PhoneNumber3)
VALUES (1, 2718353881, 3385531980, 5324571342),
       (2, 6007163571, 6875099415, 7756620787),
       (3, 9439250939, NULL, NULL);

SELECT EmployeeID,
       PhoneType,
       PhoneValue
FROM dbo.Contact c
UNPIVOT
(
    PhoneValue
    FOR PhoneType IN ([PhoneNumber1], [PhoneNumber2], [PhoneNumber3])
) AS p;
-- Out:
-- Commands completed successfully.
-- (3 rows affected)
-- (7 rows affected)
-- Total execution time: 00:00:00.068
-- <table><tr><th>EmployeeID</th><th>PhoneType</th><th>PhoneValue</th></tr><tr><td>1</td><td>PhoneNumber1</td><td>2718353881</td></tr><tr><td>1</td><td>PhoneNumber2</td><td>3385531980</td></tr><tr><td>1</td><td>PhoneNumber3</td><td>5324571342</td></tr><tr><td>2</td><td>PhoneNumber1</td><td>6007163571</td></tr><tr><td>2</td><td>PhoneNumber2</td><td>6875099415</td></tr><tr><td>2</td><td>PhoneNumber3</td><td>7756620787</td></tr><tr><td>3</td><td>PhoneNumber1</td><td>9439250939</td></tr></table>

-- %%
-- 6-12. Reusing Common Subqueries in a Query

WITH cte AS
(
SELECT SalesOrderID
FROM Sales.SalesOrderDetail
WHERE UnitPrice BETWEEN 1900 AND 2000
)
SELECT s.PurchaseOrderNumber
FROM Sales.SalesOrderHeader s
WHERE EXISTS (SELECT SalesOrderID
              FROM cte
              WHERE SalesOrderID = s.SalesOrderID );
-- Out:
-- (7 rows affected)
-- Total execution time: 00:00:00.077
-- <table><tr><th>PurchaseOrderNumber</th></tr><tr><td>PO7569171528</td></tr><tr><td>PO2146113582</td></tr><tr><td>PO12586169040</td></tr><tr><td>PO13543119495</td></tr><tr><td>PO5858172038</td></tr><tr><td>PO10440182311</td></tr><tr><td>PO12586178184</td></tr></table>

-- %%
-- 6-13. Querying Recursive Tables

CREATE TABLE dbo.Company 
    ( 
    CompanyID INT NOT NULL

    PRIMARY KEY, 
    ParentCompanyID INT NULL, 
    CompanyName VARCHAR(25) NOT NULL 
    ); 

INSERT dbo.Company 
    (CompanyID, ParentCompanyID, CompanyName) 

VALUES (1, NULL, 'Mega-Corp'), 
    (2, 1, 'Mediamus-Corp'), 
    (3, 1, 'KindaBigus-Corp'), 
    (4, 3, 'GettinSmaller-Corp'), 
    (5, 4, 'Smallest-Corp'), 
    (6, 5, 'Puny-Corp'), 
    (7, 5, 'Small2-Corp');
-- Out:
-- (7 rows affected)
-- Total execution time: 00:00:00.983

-- %%
WITH CompanyTree(ParentCompanyID, CompanyID, CompanyName, CompanyLevel) AS 
( 
SELECT ParentCompanyID,
    CompanyID, 
    CompanyName, 
    0 AS CompanyLevel 
FROM dbo.Company 
WHERE ParentCompanyID IS NULL 
UNION ALL 

SELECT c.ParentCompanyID, 
    c.CompanyID, 
    c.CompanyName, 
    p.CompanyLevel + 1 
FROM dbo.Company c 
    INNER JOIN CompanyTree p 
        ON c.ParentCompanyID = p.CompanyID 
) 

SELECT ParentCompanyID, 
    CompanyID, 
    CompanyName, 
    CompanyLevel 
FROM CompanyTree;
-- Out:
-- (7 rows affected)
-- Total execution time: 00:00:00.045
-- <table><tr><th>ParentCompanyID</th><th>CompanyID</th><th>CompanyName</th><th>CompanyLevel</th></tr><tr><td>NULL</td><td>1</td><td>Mega-Corp</td><td>0</td></tr><tr><td>1</td><td>2</td><td>Mediamus-Corp</td><td>1</td></tr><tr><td>1</td><td>3</td><td>KindaBigus-Corp</td><td>1</td></tr><tr><td>3</td><td>4</td><td>GettinSmaller-Corp</td><td>2</td></tr><tr><td>4</td><td>5</td><td>Smallest-Corp</td><td>3</td></tr><tr><td>5</td><td>6</td><td>Puny-Corp</td><td>4</td></tr><tr><td>5</td><td>7</td><td>Small2-Corp</td><td>4</td></tr></table>

-- %%
-- 6-14. Hard-Coding the Results from a Query 

-- Utilize the VALUES clause to create a table value constructor. 

SELECT * 
FROM (VALUES ('George', 'Washington'), 
            ('Thomas', 'Jefferson'), 
            ('John', 'Adams'), 
            ('James', 'Madison'), 
            ('James', 'Monroe'), 
            ('John Quincy', 'Adams'), 
            ('Andrew', 'Jackson'), 
            ('Martin', 'Van Buren'),
            ('William', 'Harrison'), 
            ('John', 'Tyler') 
            ) dtPresidents(FirstName, LastName);
-- Out:
-- (10 rows affected)
-- Total execution time: 00:00:00.020
-- <table><tr><th>FirstName</th><th>LastName</th></tr><tr><td>George</td><td>Washington</td></tr><tr><td>Thomas</td><td>Jefferson</td></tr><tr><td>John</td><td>Adams</td></tr><tr><td>James</td><td>Madison</td></tr><tr><td>James</td><td>Monroe</td></tr><tr><td>John Quincy</td><td>Adams</td></tr><tr><td>Andrew</td><td>Jackson</td></tr><tr><td>Martin</td><td>Van Buren</td></tr><tr><td>William</td><td>Harrison</td></tr><tr><td>John</td><td>Tyler</td></tr></table>
